# %%
import numpy as numpy
import matplotlib.pyplot as plt

# %%
x = np.random.normal(0, 1.0, 1000000)

bins = np.linspace(-4, 4, 400)
plt.hist(x, bins)

plt.xlabel('scores')
plt.ylabel('count')

plt.show()
